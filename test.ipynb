# %%
import speedruncompy

request = speedruncompy.GetGameData(gameUrl="hollowknight")

result = await request.perform_async()

result
# Out:
# {'game': {'id': '76rqmld8',
#   'name': 'Hollow Knight',
#   'url': 'hollowknight',
#   'type': 'game',
#   'loadtimes': True,
#   'milliseconds': True,
#   'igt': False,
#   'verification': True,
#   'autoVerify': False,
#   'requireVideo': True,
#   'emulator': -1,
#   'defaultTimer': 0,
#   'validTimers': [0, 1],
#   'releaseDate': 1487894400,
#   'addedDate': 1488743594,
#   'touchDate': 1703987083,
#   'coverPath': '/gameasset/76rqmld8/cover?v=a2d917a',
#   'trophy1stPath': '/themeasset/g84370r3/1st?v=9e16d6b',
#   'trophy2ndPath': '/themeasset/g84370r3/2nd?v=bb33e14',
#   'trophy3rdPath': '/themeasset/g84370r3/3rd?v=0758a45',
#   'runCommentsMode': 1,
#   'runCount': 7640,
#   'activePlayerCount': 145,
#   'totalPlayerCount': 2402,
#   'boostReceivedCount': 30,
#   'boostDistinctDonorsCount': 6,
# ...
